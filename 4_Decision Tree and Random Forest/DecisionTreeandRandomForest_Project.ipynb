# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# In C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
df=pd.read_csv('loan_data.csv')

# %%
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
plt.hist(df['fico'],bins=30)
# Out:
# (array([  3.,   1.,   8.,   5., 214., 131., 541., 438., 395., 963., 548.,
#         974., 472., 839., 424., 388., 691., 313., 560., 258., 451., 142.,
#         158., 258.,  85., 173.,  55.,  78.,   6.,   6.]),
#  array([612.        , 619.16666667, 626.33333333, 633.5       ,
#         640.66666667, 647.83333333, 655.        , 662.16666667,
#         669.33333333, 676.5       , 683.66666667, 690.83333333,
#         698.        , 705.16666667, 712.33333333, 719.5       ,
#         726.66666667, 733.83333333, 741.        , 748.16666667,
#         755.33333333, 762.5       , 769.66666667, 776.83333333,
#         784.        , 791.16666667, 798.33333333, 805.5       ,
#         812.66666667, 819.83333333, 827.        ]),
#  <BarContainer object of 30 artists>)

# %%
sns.set_style('darkgrid')
df[df['credit.policy']==1]['fico'].plot(kind='hist',bins=30,label='Credit.Policy=1',alpha=0.6)
df[df['credit.policy']==0]['fico'].plot(kind='hist',bins=30,label='Credit.Policy=0',alpha=0.6)
plt.xlabel('FICO')
plt.legend()

# %%
df[df['not.fully.paid']==1]['fico'].plot(kind='hist',bins=30,label='not.fully.paid=1',alpha=0.6)
df[df['not.fully.paid']==0]['fico'].plot(kind='hist',bins=30,label='not.fully.paid=0',alpha=0.6)

plt.xlabel('FICO')
plt.legend()

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['purpose'],hue=df['not.fully.paid'])
plt.tight_layout()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(x='fico',y='int.rate',data=df)
# Out:
# <AxesSubplot:xlabel='fico', ylabel='int.rate'>

# %%
sns.jointplot(x='fico',y='int.rate',data=df)

# %%
sns.lmplot(x='fico',y='int.rate',hue='credit.policy',data=df,col='not.fully.paid',palette="Set1")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
pd.get_dummies(df['purpose'])
# Out:
#       all_other  credit_card  debt_consolidation  educational  \
# 0             0            0                   1            0
# 1             0            1                   0            0
# 2             0            0                   1            0
# 3             0            0                   1            0
# 4             0            1                   0            0
# ...         ...          ...                 ...          ...
# 9573          1            0                   0            0
# 9574          1            0                   0            0
# 9575          0            0                   1            0
# 9576          0            0                   0            0
# 9577          0            0                   1            0
#
#       home_improvement  major_purchase  small_business
# 0                    0               0               0
# 1                    0               0               0
# ...

# %%
cat_feats = ['purpose']

# %%
cat_feats
# Out:
# ['purpose']

# %%
#columns : list-like, default None #Column names in the DataFrame to be encoded.#If `columns` is None then all the columns with
 #`object` or `category` dtype will be converted.
final_data = pd.get_dummies(df,columns=cat_feats,drop_first=True)
final_data.head()
# Out:
#    credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1    0.1189       829.10       11.350407  19.48   737
# 1              1    0.1071       228.22       11.082143  14.29   707
# 2              1    0.1357       366.86       10.373491  11.63   682
# 3              1    0.1008       162.34       11.350407   8.10   712
# 4              1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid  purpose_credit_card  purpose_debt_consolidation  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=final_data.drop('not.fully.paid',axis=1)
y=df['not.fully.paid']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test,pred))
print('\n')
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      2423
#            1       0.19      0.21      0.20       451
#
#     accuracy                           0.73      2874
#    macro avg       0.52      0.52      0.52      2874
# weighted avg       0.75      0.73      0.74      2874
#
#
#
# [[2014  409]
#  [ 356   95]]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred1=rfc.predict(X_test)

# %%
print(classification_report(y_test,pred1))
print('\n')
print(confusion_matrix(y_test,pred1))
#random forest perfomrs better
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91      2423
#            1       0.38      0.02      0.03       451
#
#     accuracy                           0.84      2874
#    macro avg       0.61      0.51      0.47      2874
# weighted avg       0.77      0.84      0.78      2874
#
#
#
# [[2410   13]
#  [ 443    8]]
